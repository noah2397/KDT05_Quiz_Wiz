# %%
import pandas as pd

df = pd.read_csv("./Data/LOW.csv")
# df의 "A"열이 '\x0c'와 다른 것만 저장
df = df[df["A"] != '\x0c']
df=df.dropna()
df.info()
df.to_csv("./Data/LOW2.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22781 entries, 0 to 23078
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       22781 non-null  object
#  1   K1      22781 non-null  object
#  2   K2      22781 non-null  object
#  3   K3      22781 non-null  object
#  4   K4      22781 non-null  object
#  5   A       22781 non-null  object
# dtypes: object(6)
# memory usage: 1.2+ MB

# %%
df = df.drop_duplicates()
df.info()
df.to_csv("./Data/LOW2.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22560 entries, 0 to 23078
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       22560 non-null  object
#  1   K1      22560 non-null  object
#  2   K2      22560 non-null  object
#  3   K3      22560 non-null  object
#  4   K4      22560 non-null  object
#  5   A       22560 non-null  object
# dtypes: object(6)
# memory usage: 1.2+ MB

# %%
import pandas as pd

df = pd.read_csv("MIDDLE.csv")
# df의 "A"열이 '\x0c'와 다른 것만 저장
df = df[df["A"] != '\x0c']
df=df.dropna()
df.info()
df.to_csv("MIDDLE2.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7168 entries, 0 to 7288
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       7168 non-null   object
#  1   K1      7168 non-null   object
#  2   K2      7168 non-null   object
#  3   K3      7168 non-null   object
#  4   K4      7168 non-null   object
#  5   A       7168 non-null   object
# dtypes: object(6)
# memory usage: 392.0+ KB

# %%
import pandas as pd

df = pd.read_csv("./Data/DIFFICULT.csv")
# df의 "A"열이 '\x0c'와 다른 것만 저장
df = df[df["A"] != '\x0c']
df=df.dropna()
df.info()
df.to_csv("./Data/DIFFICULT2.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10847 entries, 0 to 10927
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       10847 non-null  object
#  1   K1      10847 non-null  object
#  2   K2      10847 non-null  object
#  3   K3      10847 non-null  object
#  4   K4      10847 non-null  object
#  5   A       10847 non-null  object
# dtypes: object(6)
# memory usage: 593.2+ KB

# %%
df = pd.read_csv("./Data/TOTAL.csv")
# 새로운 열 AN을 생성하고, A에 있는 열의 값이 K1의 열의 값과 같다면 0, K2와 같다면 1, K3와 같다면 2, K4와 같다면 3로 설정
# AN 열 생성 및 값 설정
def set_an_value(row):
    if row['A'] == row['K1']:
        return 0
    elif row['A'] == row['K2']:
        return 1
    elif row['A'] == row['K3']:
        return 2
    elif row['A'] == row['K4']:
        return 3
    else:
        return None  # 예외 처리 필요 시 설정

df['AN'] = df.apply(set_an_value, axis=1)
df
# Out:
#                                                Q          K1            K2  \
# 0                                 写真帳」を英語でいうと何 ?  loose leaf  account book
# 1                       鮭の内臓をとって、塩漬けにしたものを何という ?       さらまき鮭         はらまき鮭
# 2               次のうち、約21kmの距離で行われるマラソン競技はどれ ?  _      フルマフソン      ハーフマラフソン
# 3                     秘の暑い時に、風を起こすために用いるものはどれ ?2        うちきさ           うちわ
# 4                    関門海峡を挟んで九州と面している山口県の都市はどこ ?         上関市           下関市
# ...                                          ...         ...           ...
# 23179             アニメ「姫ちゃんのリボン」主題歌を担当していたグループは2?        SMAP            窟者
# 23180    元プロ野球選手・小宮山悟はサッカーー好きで有名だが、どこのチームのサポーター?       浦和レッズ       横浜Fマリノス
# 23181    「有川口浩探検際」や「TVチャンピオン」のナレーターとしておなじみの声優は誰?        田中信夫          田中秀幸
# 23182  少女漫画『東京ミュウミュウ』で、変身すると猫の耳としっぽが生える主人公の名前は何?       桃宮れもん         桃宮いちご
# 23183            4コマ漫画雑誌 『まんがライフ』を発行している出版和計はどこ2         双葉視           芳文福
#
#              K3         K4         A   AN
# ...

# %%
df.duplicated().sum()
# 중복된 행 제거
df = df.drop_duplicates()
df.iloc[:,:]
# Out:
#                                                Q          K1            K2  \
# 0                                 写真帳」を英語でいうと何 ?  loose leaf  account book
# 1                       鮭の内臓をとって、塩漬けにしたものを何という ?       さらまき鮭         はらまき鮭
# 2               次のうち、約21kmの距離で行われるマラソン競技はどれ ?  _      フルマフソン      ハーフマラフソン
# 3                     秘の暑い時に、風を起こすために用いるものはどれ ?2        うちきさ           うちわ
# 4                    関門海峡を挟んで九州と面している山口県の都市はどこ ?         上関市           下関市
# ...                                          ...         ...           ...
# 23179             アニメ「姫ちゃんのリボン」主題歌を担当していたグループは2?        SMAP            窟者
# 23180    元プロ野球選手・小宮山悟はサッカーー好きで有名だが、どこのチームのサポーター?       浦和レッズ       横浜Fマリノス
# 23181    「有川口浩探検際」や「TVチャンピオン」のナレーターとしておなじみの声優は誰?        田中信夫          田中秀幸
# 23182  少女漫画『東京ミュウミュウ』で、変身すると猫の耳としっぽが生える主人公の名前は何?       桃宮れもん         桃宮いちご
# 23183            4コマ漫画雑誌 『まんがライフ』を発行している出版和計はどこ2         双葉視           芳文福
#
#              K3         K4         A   AN
# ...

# %%
import pandas as pd


# 각 튜플 안에는 (A, AN, Q+k1+k2+k3+k4)로 구성된 리스트 생성
result_list = []
for index, row in df.iterrows():
    A = row['A']
    AN = row['AN']
    Q = row['Q']
    combined_Q_choices = f"{Q} {row['K1']} {row['K2']} {row['K3']} {row['K4']}"
    result_list.append((A, AN, combined_Q_choices))

# result_list를 txt에 저장
with open("result.txt", "w") as f:
    for result in result_list:
        f.write(f"{result}\n")

# %%
import MeCab

# MeCab 인스턴스 생성
mecab = MeCab.Tagger('-Owakati')

# 토큰화할 문장
sentence = "たけるとショーゴからなるお笑いコンビ、〇〇ホテイソン。〇〇は何"

# 문장 토큰화
tokens = mecab.parse(sentence)

# 토큰화된 결과 출력
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import MeCab
#       3 # MeCab 인스턴스 생성
#       4 mecab = MeCab.Tagger('-Owakati')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\MeCab.py:15
#      13     from . import _MeCab
#      14 else:
# ---> 15     import _MeCab
#      17 try:
#      18     import builtins as __builtin__
#
# ImportError: DLL load failed while importing _MeCab: 지정된 모듈을 찾을 수 없습니다.

# %%
from janome.tokenizer import Tokenizer

def analyze_japanese_text(text):
    tokenizer = Tokenizer()
    tokens = tokenizer.tokenize(text)
    for token in tokens:
        print("표면형: {}, 품사: {}".format(token.surface, token.part_of_speech))

# 예제 텍스트
japanese_text = "すもももももももものうち"

# 형태소 분석 실행
analyze_japanese_text(japanese_text)
# Out:
# 표면형: すもも, 품사: 名詞,一般,*,*
# 표면형: も, 품사: 助詞,係助詞,*,*
# 표면형: もも, 품사: 名詞,一般,*,*
# 표면형: も, 품사: 助詞,係助詞,*,*
# 표면형: もも, 품사: 名詞,一般,*,*
# 표면형: の, 품사: 助詞,連体化,*,*
# 표면형: うち, 품사: 名詞,非自立,副詞可能,*

# %%
import pandas as pd

df = pd.read_csv("./Data/DIFFICULT.csv")
df.duplicated().sum()
# Out:
# 177
